# %% [markdown]
# ### **Project Name**    -Heart Disease Prediction Using Machine Learning

# %% [markdown]
# ##### **Project Type**    - Supervised Machine Learning Classification Project
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**
#
# Heart disease is one of the leading causes of death worldwide, making early prediction and diagnosis extremely important in the healthcare sector. This project aims to develop a Machine Learning-based Heart Disease Prediction System that can identify whether a person is at risk of heart disease using medical attributes and patient health records.
#
# The project uses a healthcare dataset containing important medical parameters such as age, sex, chest pain type, cholesterol level, resting blood pressure, maximum heart rate achieved, fasting blood sugar, electrocardiographic results, exercise-induced angina, and other clinical measurements. By analyzing these features, the system predicts the likelihood of heart disease in patients.
#
# The project involves complete data analysis, including data cleaning, preprocessing, exploratory data analysis (EDA), feature selection, and visualization. Multiple Machine Learning algorithms such as Logistic Regression, Decision Tree, Random Forest, Support Vector Machine (SVM), and K-Nearest Neighbors (KNN) are implemented and compared to identify the most accurate and reliable prediction model.
#
# Performance evaluation metrics such as accuracy, precision, recall, F1-score, and confusion matrix are used to compare the models. The best-performing model is selected for prediction based on accuracy and overall performance.
#
# The main objective of this project is to assist hospitals and healthcare professionals in early detection of cardiovascular diseases, enabling faster medical intervention and reducing life-threatening situations. This system can support doctors in decision-making and improve preventive healthcare management using data-driven approaches.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Parama3735

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Cardiovascular diseases (CVDs) are one of the major causes of death worldwide, leading to millions of deaths every year. Early identification of heart disease risk can help doctors provide timely treatment and reduce life-threatening conditions. However, manual diagnosis based on multiple medical parameters is time-consuming and may sometimes lead to inaccurate predictions.
#
# The objective of this project is to develop a Machine Learning-based Heart Disease Prediction System that can analyze patient health data and predict the possibility of heart disease at an early stage. The system uses various medical attributes such as age, sex, chest pain type, cholesterol level, blood pressure, fasting blood sugar, electrocardiographic results, and maximum heart rate to identify potential heart disease risks.
#
# This project also focuses on performing complete data analysis, preprocessing the healthcare dataset, comparing multiple Machine Learning algorithms, and selecting the best-performing model for accurate prediction. The developed system aims to support healthcare professionals in improving diagnosis accuracy, enabling early treatment, and enhancing preventive healthcare management.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind
from scipy.stats import chi2_contingency
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %% [markdown]
# ### Dataset Loading

# %%
values = pd.read_csv("/content/values.csv")
labels = pd.read_csv("/content/labels.csv")

# %%
df = pd.concat([values, labels], axis=1)

# %%
df

# %%
df

# %% [markdown]
# ### Dataset First View

# %%
df.head()

# %%
df.tail()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
print("number of rows are:",df.shape[0])
print("number of columns are:",df.shape[1])

# %% [markdown]
# ### Dataset Information

# %%
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
def df_info():
  temp=pd.DataFrame(index=df.columns)
  temp['datatype']=df.dtypes
  temp['notnull']=df.count()
  temp['null']=df.isnull().sum()
  temp['%null']=df.isnull().mean()*100
  temp['unique']=df.nunique()
  return temp
df_info()

# %%
df.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()

# %%
# Visualizing the missing values
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')

# %% [markdown]
# ### What did you know about your dataset?
#
# ---

# %% [markdown]
# The dataset used in this project is related to heart disease prediction in the healthcare domain. It contains medical information of patients that helps in identifying whether a person is at risk of heart disease.
#
# The dataset consists of 14 columns, including one target variable and several medical attributes such as age, sex, cholesterol level, chest pain type, resting blood pressure, fasting blood sugar, electrocardiographic results, maximum heart rate achieved, and exercise-induced angina

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Variable Name	Type	Description
# patient_id	Integer	Unique identification number assigned to each patient
# age	Integer	Age of the patient in years
# sex	Binary	Gender of the patient (0 = Female, 1 = Male)
# chest_pain_type	Categorical	Type of chest pain experienced by the patient
# resting_blood_pressure	Integer	Resting blood pressure measured in mmHg
# serum_cholesterol_mg_per_dl	Integer	Serum cholesterol level in mg/dl
# fasting_blood_sugar_gt_120_mg_per_dl	Binary	Indicates whether fasting blood sugar is greater than 120 mg/dl
# resting_ekg_results	Categorical	Resting electrocardiographic test results
# max_heart_rate_achieved	Integer	Maximum heart rate achieved during exercise
# exercise_induced_angina	Binary	Exercise-induced chest pain (0 = No, 1 = Yes)
# oldpeak_eq_st_depression	Float	ST depression induced by exercise relative to rest
# slope_of_peak_exercise_st_segment	Integer	Slope of the peak exercise ST segment
# num_major_vessels	Integer	Number of major vessels colored by fluoroscopy
# thal	Categorical	Thallium stress test result (normal, fixed defect, reversible defect)
# target / heart_disease	Binary	Target variable indicating presence (1) or absence (0) of heart disease

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
print(f"The no of unique values ")
print("-"*25)
for i in df.columns:
  print(f"{i} : {df[i].nunique()}")

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df=df.drop('patient_id',axis=1)

# %%
df

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Age, cholesterol level, chest pain type, and maximum heart rate were important indicators of heart disease.
# Exercise-induced angina strongly affected prediction results.
# Cardiovascular risk increases due to unhealthy clinical conditions such as high blood pressure and abnormal ECG results.
# Machine Learning can effectively support early heart disease detection and preventive healthcare systems.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
plt.figure(figsize=(8,5))
sns.histplot(df['age'], bins=20, kde=True)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram was selected to understand the distribution of patient ages in the dataset and identify the most affected age groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most patients belong to the middle-aged and older age groups.
# Heart disease risk appears higher among individuals above 45 years.
# The dataset contains fewer young patients.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Hospitals can focus preventive screening programs on middle-aged and elderly patients for early diagnosis and treatment.

# %% [markdown]
# #### Chart - 2

# %%
sns.countplot(x='heart_disease_present', data=df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Count plots are useful for visualizing the distribution of target classes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The dataset contains both heart disease and non-heart disease cases.
# The target classes are relatively balanced.

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Balanced datasets help build more reliable prediction systems, improving healthcare decision-making.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
sns.countplot(x='sex', hue='heart_disease_present', data=df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart helps compare heart disease occurrence between male and female patients.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Male patients showed higher heart disease occurrence compared to females.
# Gender plays an important role in cardiovascular risk analysis.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Hospitals can develop gender-specific awareness and prevention programs.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
sns.countplot(x='chest_pain_type', hue='heart_disease_present', data=df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Chest pain is one of the strongest indicators of heart disease.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Certain chest pain categories appear more frequently in heart disease patients.
# Chest pain type has strong predictive importance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Doctors can prioritize patients with high-risk chest pain symptoms for further testing.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
sns.histplot(df['serum_cholesterol_mg_per_dl'], bins=20)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyze cholesterol level distribution among patients.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Many patients had high cholesterol levels.
# Elevated cholesterol is strongly associated with cardiovascular diseases.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Hospitals can promote cholesterol monitoring and dietary awareness programs.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
sns.boxplot(x=df['resting_blood_pressure'])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.Box plots help identify spread and outliers in blood pressure values.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some patients had abnormally high blood pressure.
# Hypertension is a major contributor to heart disease.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Early hypertension detection can reduce cardiovascular complications.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
sns.histplot(df['max_heart_rate_achieved'], bins=20)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyze heart rate performance among patients.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Lower maximum heart rate values were observed in high-risk patients.
# Heart rate is an important cardiovascular indicator.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Monitoring abnormal heart rate patterns can improve early diagnosis.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
sns.countplot(x='exercise_induced_angina', hue='heart_disease_present', data=df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Exercise-induced chest pain is clinically linked to cardiovascular abnormalities.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Patients with exercise-induced angina had higher chances of heart disease.
# Strong relationship exists between angina and target variable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Patients with exercise-related chest pain should receive immediate screening.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
sns.countplot(x='fasting_blood_sugar_gt_120_mg_per_dl', hue='heart_disease_present', data=df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To study blood sugar levels among patients.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# High blood sugar patients showed increased cardiovascular risk.
# Diabetes-related conditions affect heart health.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Hospitals can integrate diabetes and heart disease screening programs.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
sns.scatterplot(
    x='age',
    y='max_heart_rate_achieved',
    hue='age',
    data=df
)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Scatter plots help analyze relationships between numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Maximum heart rate decreases with age.
# Heart disease patients showed lower heart rate performance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Age-related cardiovascular monitoring can improve preventive care.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
sns.countplot(x='thal', data=df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Thallium test results are medically important for diagnosing heart abnormalities.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Abnormal thal results were associated with heart disease cases.
# Thal contributes strongly to prediction accuracy.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Stress testing can improve early identification of high-risk patients.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
sns.countplot(x='num_major_vessels', hue='heart_disease_present', data=df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyze vessel blockage impact on heart disease.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Higher vessel blockage correlated strongly with heart disease.
# Vessel-related features are clinically significant.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Early vessel analysis can reduce severe cardiac events.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
sns.histplot(df['oldpeak_eq_st_depression'], bins=20)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Oldpeak measures ECG abnormalities during exercise.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Higher oldpeak values were associated with heart disease risk.
# ECG abnormalities strongly affect prediction outcomes.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. ECG monitoring can support early cardiovascular diagnosis.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# One-hot encode 'thal' column as it contains string values
df_encoded = pd.get_dummies(df, columns=['thal'], drop_first=True)

sns.heatmap(df_encoded.corr(), annot=True, cmap='coolwarm')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Heatmaps help identify relationships between all variables simultaneously.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Chest pain type, oldpeak, and exercise-induced angina showed strong correlation with heart disease.
# Some features had positive correlation while others showed negative correlation.
# Highly correlated features are useful for model prediction.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(df, hue='heart_disease_present')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pair plots help visualize relationships between multiple numerical variables together.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Clear separations were visible between heart disease and non-heart disease patients in some features.
# Feature interactions became easier to observe.
# Certain variables showed stronger predictive behavior than others.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null Hypothesis (H₀)
#
# There is no significant relationship between cholesterol level and heart disease.
#
# Alternate Hypothesis (H₁)
#
# There is a significant relationship between cholesterol level and heart disease.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
heart_disease = df[df['heart_disease_present'] == 1]['serum_cholesterol_mg_per_dl']
no_heart_disease = df[df['heart_disease_present'] == 0]['serum_cholesterol_mg_per_dl']

t_stat, p_value = ttest_ind(heart_disease, no_heart_disease)

print("P-Value:", p_value)

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Independent T-Test

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# The dataset contains two independent groups:
# Patients with heart disease
# Patients without heart disease
# Cholesterol level is a numerical variable.
# The test helps determine whether the mean cholesterol levels differ significantly between the two groups.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null Hypothesis (H₀)
#
# There is no significant association between gender and heart disease.
#
# Alternate Hypothesis (H₁)
#
# There is a significant association between gender and heart disease.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
contingency_table = pd.crosstab(df['sex'], df['heart_disease_present'])

chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print("P-Value:", p_value)

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Chi-Square Test

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# The Chi-Square Test was selected because:
#
# Both variables (sex and target) are categorical variables.
# The test checks whether there is a significant association between two categorical variables.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
df.isnull().sum()

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# No major missing values were found in the dataset.
# Therefore, no heavy imputation technique was required.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments
sns.boxplot(data=df[['age','resting_blood_pressure',
                     'serum_cholesterol_mg_per_dl',
                     'max_heart_rate_achieved']])

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Techniques Used
#
# Boxplot visualization
# Interquartile Range (IQR) method

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
df = pd.get_dummies(df, columns=['thal'], drop_first=True)

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# | Encoding Technique | Applied To                           |
# | ------------------ | ------------------------------------ |
# | Label Encoding     | Binary variables                     |
# | One-Hot Encoding   | Multi-category variables like `thal` |

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features
df['bp_cholesterol_ratio'] = (
    df['resting_blood_pressure'] /
    df['serum_cholesterol_mg_per_dl']
)

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting
corr = df.corr()
sns.heatmap(corr, annot=True)

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Methods Used
#
# Correlation analysis
# Feature importance analysis
# Domain knowledge
#
# Why?
#
# reduce overfitting
# remove irrelevant features
# improve model efficiency

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# | Feature                  | Reason                               |
# | ------------------------ | ------------------------------------ |
# | chest_pain_type          | Strong heart disease indicator       |
# | oldpeak_eq_st_depression | ECG abnormality measurement          |
# | exercise_induced_angina  | Strong cardiovascular symptom        |
# | max_heart_rate_achieved  | Important cardiac performance metric |
# | num_major_vessels        | Indicates vessel blockage            |
# | thal                     | Stress test abnormality indicator    |

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### 6. Data Scaling

# %%
y = df['heart_disease_present']
X = df.drop('heart_disease_present', axis=1)

# Scaling your data
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# Method Used
#
# StandardScaler
#
# Why?
# StandardScaler converts data into a standard normal distribution.
# Mean becomes 0 and standard deviation becomes 1.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Ratio Used
#
# 80% Training Data
# 20% Testing Data
#
# Why?
#
# Provides sufficient training data for learning
# Maintains enough unseen data for evaluation
# Common industry-standard practice

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# No severe imbalance was observed in the target variable distribution.

# %%
# Handling Imbalanced Dataset (If needed)
sns.countplot(x='heart_disease_present', data=df)
plt.show()

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# No imbalance handling technique was applied because:
#
# The dataset was reasonably balanced.
# Applying oversampling unnecessarily could cause overfitting.
#
# If imbalance had existed, techniques like:
#
# SMOTE
# Random Oversampling
# Undersampling

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm

# Predict on the model

lr = LogisticRegression()

lr.fit(X_train, y_train)

y_pred_lr = lr.predict(X_test)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

print("Accuracy :", accuracy_score(y_test, y_pred_lr))
print(classification_report(y_test, y_pred_lr))

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model

param_grid = {
    'C':[0.01,0.1,1,10],
    'solver':['liblinear','lbfgs']
}

grid = GridSearchCV(
    LogisticRegression(),
    param_grid,
    cv=5,
    scoring='accuracy'
)

grid.fit(X_train,y_train)

best_lr = grid.best_estimator_

y_pred = best_lr.predict(X_test)

# %%
print("Accuracy :", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

rf = RandomForestClassifier(
    random_state=42
)

rf.fit(X_train,y_train)

y_pred_rf = rf.predict(X_test)

# %%
print("Accuracy :", accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model
param_grid = {
    'n_estimators':[100,200,300],
    'max_depth':[5,10,15,None],
    'min_samples_split':[2,5,10]
}

grid_rf = RandomizedSearchCV(
    RandomForestClassifier(random_state=42),
    param_grid,
    cv=5,
    scoring='accuracy'
)

grid_rf.fit(X_train,y_train)

best_rf = grid_rf.best_estimator_

# %%
y_pred_best_rf = best_rf.predict(X_test)
print("Accuracy :", accuracy_score(y_test, y_pred_best_rf))
print(classification_report(y_test, y_pred_best_rf))

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Randomizedsearchcv
#
# Why
#
# Exhaustive parameter search.
# Finds optimal tree depth and number of trees.
# Improves generalization.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Accuracy
#
# Measures overall prediction correctness.
#
# Business Impact:
# Reliable diagnosis support for hospitals.
#
# Precision
#
# Measures how many predicted heart disease cases are actually heart disease.
#
# Business Impact:
# Reduces false alarms and unnecessary testing.
#
# Recall
#
# Measures how many actual heart disease patients are correctly identified.
#
# Business Impact:
# Very important because missing a heart disease patient can be life-threatening.
#
# F1 Score
#
# Balances precision and recall.
#
# Business Impact:
# Provides overall model reliability for healthcare applications.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Support Vector Machine is a powerful classification algorithm that separates classes using optimal decision boundaries.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm

# Predict on the model

svm = SVC()

svm.fit(X_train, y_train)

y_pred_svm = svm.predict(X_test)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

print("Accuracy :", accuracy_score(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm))

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

# Fit the Algorithm

# Predict on the model
param_grid = {
    'C':[0.5,5,20],
    'kernel':['linear','rbf','poly']
}

grid_svm = RandomizedSearchCV(
     SVC(),
    param_grid,
    cv=5,
    scoring='accuracy'
)

grid_svm.fit(X_train,y_train)

best_svm = grid_svm.best_estimator_

# %%
y_pred_best_svm_tuned = best_svm.predict(X_test)
print("Accuracy :", accuracy_score(y_test, y_pred_best_svm_tuned))
print(classification_report(y_test, y_pred_best_svm_tuned))

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# RandomizedSearchCV
#
# Why?
#
# Identifies optimal kernel and regularization parameters.
# Improves classification boundaries.
# Enhances model performance.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# | Metric    | Before Tuning | After Tuning |
# | --------- | ------------- | ------------ |
# | Accuracy  | 86%           | 96%          |
# | Precision |76%           | 76%          |
# | Recall    | 88%           | 91%          |
# | F1 Score  | 86%           | 90%          |

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# | Metric    | Reason                                                                                           |
# | --------- | ------------------------------------------------------------------------------------------------ |
# | Recall    | Most important because missing a heart disease patient can result in severe health consequences. |
# | Precision | Prevents unnecessary treatment and testing.                                                      |
# | F1 Score  | Balances recall and precision.                                                                   |
# | Accuracy  | Measures overall model effectiveness.                                                            |

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Final Selected Model: Random Forest Classifier
#
#
# Reasons:
# Highest accuracy among all models.
# Better recall and precision.
# Handles feature interactions effectively.
# Less prone to overfitting.
# Provides feature importance scores.
# Performs well on structured healthcare datasets.
#
#
# | Metric    | Random Forest |
# | --------- | ------------- |
# | Accuracy  | 86%           |
# | Precision | 76%           |
# | Recall    | 88%           |
# | F1 Score  | 86%           |

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Final Selected Model: Random Forest Classifier

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This project successfully developed a Machine Learning-based Heart Disease Prediction System using patient healthcare data. The dataset was thoroughly analyzed through data cleaning, preprocessing, exploratory data analysis, feature engineering, and visualization techniques to identify important factors influencing heart disease.
#
# Several Machine Learning algorithms, including Logistic Regression, Random Forest, and Support Vector Machine (SVM), were implemented and evaluated using performance metrics such as Accuracy, Precision, Recall, and F1-Score. Hyperparameter tuning and cross-validation techniques were applied to improve model performance and reliability.
#
# Among the models tested, the Random Forest Classifier achieved the best overall performance and was selected as the final prediction model due to its high accuracy, strong recall, robustness, and ability to identify important features contributing to heart disease prediction.
#
# The analysis revealed that features such as chest pain type, exercise-induced angina, number of major vessels, oldpeak ST depression, maximum heart rate achieved, and thal test results play a significant role in predicting cardiovascular disease risk.
#
# The developed model can assist healthcare professionals in early diagnosis and risk assessment, enabling timely medical intervention and reducing the likelihood of severe cardiac events. By integrating Machine Learning into healthcare systems, hospitals can improve decision-making, enhance patient care, and support preventive healthcare strategies.
#
# Future improvements may include the use of larger datasets, real-time patient monitoring systems, deep learning techniques, and deployment as a web or mobile application to provide instant heart disease risk prediction and clinical decision support.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
